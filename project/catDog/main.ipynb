# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import cluster
import imageio

# %%
def main():
    image = imageio.imread("image.jpeg")
    plt.figure(figsize=(15,8))
    plt.imshow(image)
    x,y,z = image.shape
    image_2d = image.reshape(x*y,z) # converting the image into the 2 dimensional array(metrics)
    print(image_2d.reshape)

# %%
if __name__ == "__main__":
    main()
# Out:
# <built-in method reshape of Array object at 0x7fa831cd7510>
